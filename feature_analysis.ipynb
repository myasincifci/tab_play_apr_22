# %%
import numpy as np
import matplotlib.pyplot as plt

from data import DS

# %%
X, t = DS().get_data()

# %%
X.shape, t.shape
# Out:
# ((25968, 60, 13), (25968, 2))

# %%
X0 = X[t[:,0] == 1]
X1 = X[t[:,1] == 1]

# %%
plt.plot(np.arange(60), X[0,:,0])

# %%
plt.plot(np.arange(60), X[:,:,0].mean(axis=0))

# %%
plt.plot(np.arange(60), X0[:,:,0].mean(axis=0))

# %%
plt.plot(np.arange(60), X1[:,:,0].mean(axis=0))

# %%
plt.plot(np.arange(60), X[4,:,2])

# %%
plt.plot(np.arange(60), X[0,:,0])
